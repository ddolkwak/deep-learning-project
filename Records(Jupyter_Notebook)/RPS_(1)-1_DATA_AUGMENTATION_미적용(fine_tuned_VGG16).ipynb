# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
dataset, info = tfds.load("rock_paper_scissors", as_supervised=True, with_info=True)
# Out:
# Downloading and preparing dataset 219.53 MiB (download: 219.53 MiB, generated: Unknown size, total: 219.53 MiB) to /root/tensorflow_datasets/rock_paper_scissors/3.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/2520 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/rock_paper_scissors/3.0.0.incompleteEMKXOO/rock_paper_scissors-train.tfrec…
# Generating test examples...:   0%|          | 0/372 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/rock_paper_scissors/3.0.0.incompleteEMKXOO/rock_paper_scissors-test.tfreco…
# Dataset rock_paper_scissors downloaded and prepared to /root/tensorflow_datasets/rock_paper_scissors/3.0.0. Subsequent calls will reuse this data.

# %%
info
# Out:
# tfds.core.DatasetInfo(
#     name='rock_paper_scissors',
#     full_name='rock_paper_scissors/3.0.0',
#     description="""
#     Images of hands playing rock, paper, scissor game.
#     """,
#     homepage='http://laurencemoroney.com/rock-paper-scissors-dataset',
#     data_dir=PosixGPath('/tmp/tmpswc9fikftfds'),
#     file_format=tfrecord,
#     download_size=219.53 MiB,
#     dataset_size=219.23 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(300, 300, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=3),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=372, num_shards=1>,
#         'train': <SplitInfo num_examples=2520, num_shards=2>,
#     },
#     citation="""@ONLINE {rps,
#     author = "Laurence Moroney",
#     title = "Rock, Paper, Scissors Dataset",
#     month = "feb",
#     year = "2019",
#     url = "http://laurencemoroney.com/rock-paper-scissors-dataset"
#     }""",
# )

# %%
class_names = info.features['label'].names
class_names
# Out:
# ['rock', 'paper', 'scissors']

# %%
n_classes = info.features['label'].num_classes
n_classes
# Out:
# 3

# %%
train_set_size = info.splits['train'].num_examples
test_set_size = info.splits['test'].num_examples

train_set_size, test_set_size
# Out:
# (2520, 372)

# %% [markdown]
# # Training, Validation, Test Set 분리

# %%
test_set_raw, valid_set_raw, train_set_raw = tfds.load('rock_paper_scissors', as_supervised=True, split=['test[0%:]', 'train[:15%]', 'train[15%:]'])

# %% [markdown]
# # 데이터 전처리

# %%
import keras

# %%
def preprocess(image, label):
  resized_image = tf.image.resize(image, [224, 224])
  final_image = keras.applications.vgg16.preprocess_input(resized_image)
  return final_image, label


batch_size = 50

train_set = train_set_raw.shuffle(10).repeat()
train_set = train_set_raw.map(preprocess).batch(batch_size).prefetch(1)

valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)

test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)

# %% [markdown]
# # VGG16 합성곱 기반 층 만들기

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights='imagenet',
    include_top=False)

conv_base.trainable = True

for layer in conv_base.layers[:-4]:
  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 7079424 (27.01 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %% [markdown]
# # 데이터 증식을 사용하지 않는 빠른 특성 추출

# %% [markdown]
# ## VGG16 특성과 해당 레이블 추출하기

# %%
import numpy as np


def get_features_and_labels(dataset):
  all_features = []
  all_labels = []

  for images, labels in dataset:
    preprocessed_images = keras.applications.vgg16.preprocess_input(images)
    features = conv_base.predict(preprocessed_images)
    all_features.append(features)
    all_labels.append(labels)

  return np.concatenate(all_features), np.concatenate(all_labels)  # [[1,0], [2,1]] >> [1, 0, 1, 2]

# %%
val_features, val_labels = get_features_and_labels(valid_set)
# Out:
# 2/2 [==============================] - 13s 4s/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 6s 6s/step

# %%
train_features, train_labels = get_features_and_labels(train_set)
# Out:
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 114ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 3s 3s/step

# %%
train_features.shape
# Out:
# (2142, 7, 7, 512)

# %% [markdown]
# ## 밀집 연결 분류기 정의하고 훈련하기

# %%
from keras import layers

# %%
inputs = keras.Input(shape=(7, 7, 512))
x = layers.Flatten()(inputs)  #  Dense 층에 특성을 주입하기 전 Flatten 층을 사용
x = layers.Dense(30)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(3, activation='softmax')(x)

model = keras.Model(inputs, outputs)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=1e-5),
              metrics=['accuracy'])


checkpoint = [
    keras.callbacks.ModelCheckpoint(
        filepath='rock_paper_scissors_no_augmentation',
        save_best_only=True,
        monitor='val_loss'
    )
]
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)

history = model.fit(
    train_features, train_labels,
    epochs=50,
    steps_per_epoch = 0.85 * train_set_size / batch_size,
    validation_data=(val_features, val_labels),
    callbacks=[checkpoint, early_stopping ]
)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 4s 26ms/step - loss: 7.6991 - accuracy: 0.5215 - val_loss: 0.8154 - val_accuracy: 0.8889
# Epoch 2/50
# 42/42 [==============================] - 1s 18ms/step - loss: 2.2494 - accuracy: 0.7983 - val_loss: 0.2032 - val_accuracy: 0.9524
# Epoch 3/50
# 42/42 [==============================] - 1s 19ms/step - loss: 1.1426 - accuracy: 0.8744 - val_loss: 0.0158 - val_accuracy: 0.9921
# Epoch 4/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.5450 - accuracy: 0.9239 - val_loss: 5.9123e-04 - val_accuracy: 1.0000
# Epoch 5/50
# 42/42 [==============================] - 1s 27ms/step - loss: 0.3933 - accuracy: 0.9458 - val_loss: 1.3730e-05 - val_accuracy: 1.0000
# Epoch 6/50
# 42/42 [==============================] - 1s 27ms/step - loss: 0.2788 - accuracy: 0.9533 - val_loss: 1.9450e-06 - val_accuracy: 1.0000
# Epoch 7/50
# 42/42 [==============================] - 1s 20ms/step - loss: 0.1873 - accuracy: 0.9711 - val_loss: 3.0559e-07 - val_accuracy: 1.0000
# Epoch 8/50
# 42/42 [==============================] - 1s 18ms/step - loss: 0.1701 - accuracy: 0.9701 - val_loss: 2.6238e-07 - val_accuracy: 1.0000
# Epoch 9/50
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1370 - accuracy: 0.9748 - val_loss: 4.7964e-07 - val_accuracy: 1.0000
# Epoch 10/50
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0896 - accuracy: 0.9841 - val_loss: 1.5169e-07 - val_accuracy: 1.0000
# Epoch 11/50
# 42/42 [==============================] - 1s 18ms/step - loss: 0.0760 - accuracy: 0.9869 - val_loss: 4.8566e-08 - val_accuracy: 1.0000
# Epoch 12/50
# 42/42 [==============================] - 1s 17ms/step - loss: 0.0655 - accuracy: 0.9851 - val_loss: 4.5728e-08 - val_accuracy: 1.0000
# Epoch 13/50
# 42/42 [==============================] - 1s 32ms/step - loss: 0.0685 - accuracy: 0.9879 - val_loss: 1.9868e-08 - val_accuracy: 1.0000
# Epoch 14/50
# 42/42 [==============================] - 1s 35ms/step - loss: 0.0497 - accuracy: 0.9865 - val_loss: 1.4507e-08 - val_accuracy: 1.0000
# Epoch 15/50
# 42/42 [==============================] - 2s 55ms/step - loss: 0.0562 - accuracy: 0.9897 - val_loss: 1.5768e-09 - val_accuracy: 1.0000
# Epoch 16/50
# 42/42 [==============================] - 3s 75ms/step - loss: 0.0428 - accuracy: 0.9879 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 17/50
# 42/42 [==============================] - 1s 15ms/step - loss: 0.0441 - accuracy: 0.9935 - val_loss: 3.1537e-10 - val_accuracy: 1.0000
# Epoch 18/50
# 42/42 [==============================] - 1s 13ms/step - loss: 0.0465 - accuracy: 0.9888 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 19/50
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0293 - accuracy: 0.9935 - val_loss: 3.1537e-10 - val_accuracy: 1.0000
# Epoch 20/50
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0208 - accuracy: 0.9949 - val_loss: 3.1537e-10 - val_accuracy: 1.0000

# %% [markdown]
# ## 결과 그래프로 나타내기

# %%
import matplotlib.pyplot as plt

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

# %%
plt.plot(epochs, acc, 'bo', label='Traning accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')

plt.show()

# %% [markdown]
# ## 테스트 세트에서 모델 평가하기

# %%
test_features, test_labels = get_features_and_labels(test_set)
# Out:
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 5s 5s/step

# %%
import time

test_model = keras.models.load_model(
    'rock_paper_scissors_no_augmentation'
)

start_time = time.time()
test_loss, test_acc = test_model.evaluate(test_features, test_labels)
end_time = time.time()
prediction_time = end_time - start_time
print(f'prediction time: {prediction_time}')
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6750 - accuracy: 0.8038
# prediction time: 0.2380537986755371
