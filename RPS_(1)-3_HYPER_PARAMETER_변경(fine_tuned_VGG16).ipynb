# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
dataset, info = tfds.load("rock_paper_scissors", as_supervised=True, with_info=True)
# Out:
# Downloading and preparing dataset 219.53 MiB (download: 219.53 MiB, generated: Unknown size, total: 219.53 MiB) to /root/tensorflow_datasets/rock_paper_scissors/3.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/2520 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/rock_paper_scissors/incomplete.P9039H_3.0.0/rock_paper_scissors-train.tfre…
# Generating test examples...:   0%|          | 0/372 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/rock_paper_scissors/incomplete.P9039H_3.0.0/rock_paper_scissors-test.tfrec…
# Dataset rock_paper_scissors downloaded and prepared to /root/tensorflow_datasets/rock_paper_scissors/3.0.0. Subsequent calls will reuse this data.

# %%
info
# Out:
# tfds.core.DatasetInfo(
#     name='rock_paper_scissors',
#     full_name='rock_paper_scissors/3.0.0',
#     description="""
#     Images of hands playing rock, paper, scissor game.
#     """,
#     homepage='http://laurencemoroney.com/rock-paper-scissors-dataset',
#     data_dir=PosixGPath('/tmp/tmprovbm2fxtfds'),
#     file_format=tfrecord,
#     download_size=219.53 MiB,
#     dataset_size=219.23 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(300, 300, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=3),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=372, num_shards=1>,
#         'train': <SplitInfo num_examples=2520, num_shards=2>,
#     },
#     citation="""@ONLINE {rps,
#     author = "Laurence Moroney",
#     title = "Rock, Paper, Scissors Dataset",
#     month = "feb",
#     year = "2019",
#     url = "http://laurencemoroney.com/rock-paper-scissors-dataset"
#     }""",
# )

# %%
class_names = info.features['label'].names
class_names
# Out:
# ['rock', 'paper', 'scissors']

# %%
n_classes = info.features['label'].num_classes
n_classes
# Out:
# 3

# %%
train_set_size = info.splits['train'].num_examples
test_set_size = info.splits['test'].num_examples

train_set_size, test_set_size
# Out:
# (2520, 372)

# %% [markdown]
# # Training, Validation, Test Set 분리

# %%
test_set_raw, valid_set_raw, train_set_raw = tfds.load('rock_paper_scissors', as_supervised=True, split=['test[0%:]', 'train[:15%]', 'train[15%:]'])

# %% [markdown]
# # 데이터 전처리

# %%
import keras

# %%
def preprocess(image, label):
  resized_image = tf.image.resize(image, [224, 224])
  final_image = keras.applications.vgg16.preprocess_input(resized_image)
  return final_image, label


batch_size = 50

train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(preprocess).batch(batch_size).prefetch(1)

valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)

test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)

# %% [markdown]
# # VGG16 합성곱 기반 층을 만들고 마지막에서 네 번째 층까지 모든 층 동결하기

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights='imagenet',
    include_top=False)

conv_base.trainable = True
for layer in conv_base.layers[:-4]:
  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 7079424 (27.01 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %% [markdown]
# # 데이터 증식을 사용 X

# %%
from keras import layers

# %%
inputs = keras.Input(shape=(224, 224, 3))
x = inputs
x = keras.applications.vgg16.preprocess_input(x)  # 입력 값의 스케일 조정
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(30)(x)
outputs = layers.Dense(3, activation='softmax')(x)
model = keras.Model(inputs, outputs)

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=1e-5),
              metrics=['accuracy'])

checkpoint = [
    keras.callbacks.ModelCheckpoint(
        filepath='rock_paper_scissors_no_augmentation',
        save_best_only=True,
        monitor='val_loss'
    )
]
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)

history = model.fit(
    train_set,
    epochs=50,
    steps_per_epoch = 0.85 * train_set_size / batch_size,
    validation_data=valid_set,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 52s 843ms/step - loss: 1.1341 - accuracy: 0.8898 - val_loss: 1.0680e-04 - val_accuracy: 1.0000
# Epoch 2/50
# 42/42 [==============================] - 18s 416ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 3.2849e-05 - val_accuracy: 1.0000
# Epoch 3/50
# 42/42 [==============================] - 18s 411ms/step - loss: 1.0893e-04 - accuracy: 1.0000 - val_loss: 2.9138e-05 - val_accuracy: 1.0000
# Epoch 4/50
# 42/42 [==============================] - 16s 383ms/step - loss: 8.6780e-05 - accuracy: 1.0000 - val_loss: 2.6559e-05 - val_accuracy: 1.0000
# Epoch 5/50
# 42/42 [==============================] - 16s 385ms/step - loss: 3.5538e-05 - accuracy: 1.0000 - val_loss: 2.3426e-05 - val_accuracy: 1.0000
# Epoch 6/50
# 42/42 [==============================] - 17s 396ms/step - loss: 4.5278e-05 - accuracy: 1.0000 - val_loss: 2.0170e-05 - val_accuracy: 1.0000
# Epoch 7/50
# 42/42 [==============================] - 18s 413ms/step - loss: 3.6177e-05 - accuracy: 1.0000 - val_loss: 1.8076e-05 - val_accuracy: 1.0000
# Epoch 8/50
# 42/42 [==============================] - 16s 373ms/step - loss: 3.3969e-05 - accuracy: 1.0000 - val_loss: 1.6209e-05 - val_accuracy: 1.0000
# Epoch 9/50
# 42/42 [==============================] - 17s 400ms/step - loss: 2.7674e-05 - accuracy: 1.0000 - val_loss: 1.4552e-05 - val_accuracy: 1.0000
# Epoch 10/50
# 42/42 [==============================] - 18s 421ms/step - loss: 2.5720e-05 - accuracy: 1.0000 - val_loss: 1.3213e-05 - val_accuracy: 1.0000
# Epoch 11/50
# 42/42 [==============================] - 21s 492ms/step - loss: 2.4742e-05 - accuracy: 1.0000 - val_loss: 1.2103e-05 - val_accuracy: 1.0000
# Epoch 12/50
# 42/42 [==============================] - 19s 457ms/step - loss: 1.8935e-05 - accuracy: 1.0000 - val_loss: 1.1119e-05 - val_accuracy: 1.0000
# Epoch 13/50
# 42/42 [==============================] - 16s 374ms/step - loss: 1.8808e-05 - accuracy: 1.0000 - val_loss: 1.0234e-05 - val_accuracy: 1.0000
# Epoch 14/50
# 42/42 [==============================] - 16s 382ms/step - loss: 1.6899e-05 - accuracy: 1.0000 - val_loss: 9.3260e-06 - val_accuracy: 1.0000
# Epoch 15/50
# 42/42 [==============================] - 17s 394ms/step - loss: 1.5553e-05 - accuracy: 1.0000 - val_loss: 8.6293e-06 - val_accuracy: 1.0000
# Epoch 16/50
# 42/42 [==============================] - 16s 377ms/step - loss: 1.3721e-05 - accuracy: 1.0000 - val_loss: 7.9813e-06 - val_accuracy: 1.0000
# Epoch 17/50
# 42/42 [==============================] - 16s 370ms/step - loss: 1.2891e-05 - accuracy: 1.0000 - val_loss: 7.3839e-06 - val_accuracy: 1.0000
# Epoch 18/50
# 42/42 [==============================] - 16s 377ms/step - loss: 1.1563e-05 - accuracy: 1.0000 - val_loss: 6.8508e-06 - val_accuracy: 1.0000
# Epoch 19/50
# 42/42 [==============================] - 17s 399ms/step - loss: 1.0553e-05 - accuracy: 1.0000 - val_loss: 6.3997e-06 - val_accuracy: 1.0000
# Epoch 20/50
# 42/42 [==============================] - 17s 410ms/step - loss: 1.0437e-05 - accuracy: 1.0000 - val_loss: 5.9772e-06 - val_accuracy: 1.0000
# Epoch 21/50
# 42/42 [==============================] - 16s 379ms/step - loss: 8.9772e-06 - accuracy: 1.0000 - val_loss: 5.6412e-06 - val_accuracy: 1.0000
# Epoch 22/50
# 42/42 [==============================] - 16s 372ms/step - loss: 8.6056e-06 - accuracy: 1.0000 - val_loss: 5.3284e-06 - val_accuracy: 1.0000
# Epoch 23/50
# 42/42 [==============================] - 16s 371ms/step - loss: 8.3681e-06 - accuracy: 1.0000 - val_loss: 5.0478e-06 - val_accuracy: 1.0000
# Epoch 24/50
# 42/42 [==============================] - 17s 409ms/step - loss: 7.9922e-06 - accuracy: 1.0000 - val_loss: 4.7688e-06 - val_accuracy: 1.0000
# Epoch 25/50
# 42/42 [==============================] - 16s 378ms/step - loss: 7.1825e-06 - accuracy: 1.0000 - val_loss: 4.5270e-06 - val_accuracy: 1.0000
# Epoch 26/50
# 42/42 [==============================] - 16s 368ms/step - loss: 6.3981e-06 - accuracy: 1.0000 - val_loss: 4.3012e-06 - val_accuracy: 1.0000
# Epoch 27/50
# 42/42 [==============================] - 16s 371ms/step - loss: 6.3431e-06 - accuracy: 1.0000 - val_loss: 4.1114e-06 - val_accuracy: 1.0000
# Epoch 28/50
# 42/42 [==============================] - 16s 383ms/step - loss: 6.8966e-06 - accuracy: 1.0000 - val_loss: 3.9314e-06 - val_accuracy: 1.0000
# Epoch 29/50
# 42/42 [==============================] - 17s 399ms/step - loss: 4.7505e-06 - accuracy: 1.0000 - val_loss: 3.7519e-06 - val_accuracy: 1.0000
# Epoch 30/50
# 42/42 [==============================] - 16s 371ms/step - loss: 5.9860e-06 - accuracy: 1.0000 - val_loss: 3.5974e-06 - val_accuracy: 1.0000
# Epoch 31/50
# 42/42 [==============================] - 17s 403ms/step - loss: 6.0843e-06 - accuracy: 1.0000 - val_loss: 3.4306e-06 - val_accuracy: 1.0000
# Epoch 32/50
# 42/42 [==============================] - 16s 371ms/step - loss: 3.4846e-06 - accuracy: 1.0000 - val_loss: 3.2843e-06 - val_accuracy: 1.0000
# Epoch 33/50
# 42/42 [==============================] - 16s 385ms/step - loss: 4.6726e-06 - accuracy: 1.0000 - val_loss: 3.1437e-06 - val_accuracy: 1.0000
# Epoch 34/50
# 42/42 [==============================] - 17s 388ms/step - loss: 4.4431e-06 - accuracy: 1.0000 - val_loss: 3.0210e-06 - val_accuracy: 1.0000
# Epoch 35/50
# 42/42 [==============================] - 16s 386ms/step - loss: 4.5492e-06 - accuracy: 1.0000 - val_loss: 2.9000e-06 - val_accuracy: 1.0000
# Epoch 36/50
# 42/42 [==============================] - 16s 369ms/step - loss: 3.7170e-06 - accuracy: 1.0000 - val_loss: 2.7842e-06 - val_accuracy: 1.0000
# Epoch 37/50
# 42/42 [==============================] - 16s 378ms/step - loss: 4.0034e-06 - accuracy: 1.0000 - val_loss: 2.6701e-06 - val_accuracy: 1.0000
# Epoch 38/50
# 42/42 [==============================] - 17s 392ms/step - loss: 3.9754e-06 - accuracy: 1.0000 - val_loss: 2.5619e-06 - val_accuracy: 1.0000
# Epoch 39/50
# 42/42 [==============================] - 16s 372ms/step - loss: 3.1404e-06 - accuracy: 1.0000 - val_loss: 2.4762e-06 - val_accuracy: 1.0000
# Epoch 40/50
# 42/42 [==============================] - 16s 371ms/step - loss: 3.5590e-06 - accuracy: 1.0000 - val_loss: 2.3901e-06 - val_accuracy: 1.0000
# Epoch 41/50
# 42/42 [==============================] - 17s 395ms/step - loss: 3.3281e-06 - accuracy: 1.0000 - val_loss: 2.2879e-06 - val_accuracy: 1.0000
# Epoch 42/50
# 42/42 [==============================] - 17s 394ms/step - loss: 3.7393e-06 - accuracy: 1.0000 - val_loss: 2.2084e-06 - val_accuracy: 1.0000
# Epoch 43/50
# 42/42 [==============================] - 16s 378ms/step - loss: 2.6628e-06 - accuracy: 1.0000 - val_loss: 2.1287e-06 - val_accuracy: 1.0000
# Epoch 44/50
# 42/42 [==============================] - 17s 399ms/step - loss: 2.9724e-06 - accuracy: 1.0000 - val_loss: 2.0504e-06 - val_accuracy: 1.0000
# Epoch 45/50
# 42/42 [==============================] - 16s 374ms/step - loss: 2.6726e-06 - accuracy: 1.0000 - val_loss: 1.9801e-06 - val_accuracy: 1.0000
# Epoch 46/50
# 42/42 [==============================] - 16s 386ms/step - loss: 2.7989e-06 - accuracy: 1.0000 - val_loss: 1.9114e-06 - val_accuracy: 1.0000
# Epoch 47/50
# 42/42 [==============================] - 17s 394ms/step - loss: 2.6030e-06 - accuracy: 1.0000 - val_loss: 1.8404e-06 - val_accuracy: 1.0000
# Epoch 48/50
# 42/42 [==============================] - 17s 405ms/step - loss: 2.0680e-06 - accuracy: 1.0000 - val_loss: 1.7736e-06 - val_accuracy: 1.0000
# Epoch 49/50
# 42/42 [==============================] - 16s 385ms/step - loss: 2.3879e-06 - accuracy: 1.0000 - val_loss: 1.7156e-06 - val_accuracy: 1.0000
# Epoch 50/50
# 42/42 [==============================] - 16s 370ms/step - loss: 2.4003e-06 - accuracy: 1.0000 - val_loss: 1.6503e-06 - val_accuracy: 1.0000

# %% [markdown]
# ## 결과 그래프로 나타내기

# %%
import matplotlib.pyplot as plt

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

# %%
plt.plot(epochs, acc, 'bo', label='Traning accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')

plt.show()

# %% [markdown]
# ## 테스트 세트에서 모델 평가하기

# %%
import time

test_model = keras.models.load_model(
    'rock_paper_scissors_no_augmentation'
)

start_time = time.time()
test_loss, test_acc = test_model.evaluate(test_set)
end_time = time.time()
prediction_time = end_time - start_time
print(f'prediction time: {prediction_time}')
# Out:
# 8/8 [==============================] - 2s 225ms/step - loss: 1.8713 - accuracy: 0.7366
# prediction time: 2.897307872772217
